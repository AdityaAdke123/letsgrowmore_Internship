# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaAdke123/letsgrowmore_tasks/blob/main/Letsgrowmore_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('iris.data',names = ['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)','class' ])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#               class
# ...

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   class              150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df,hue='class')
plt.show()

# %%
sns.boxplot(data=df, x="sepal width (cm)", y="class")
plt.show()

# %%
sns.boxplot(data=df, x="sepal length (cm)", y="class")
plt.show()

# %%
sns.boxplot(data=df, x="petal length (cm)", y="class")
plt.show()

# %%
sns.boxplot(data=df, x="petal width (cm)", y="class")
plt.show()

# %%
data = df.values
X = data[:,0:4]
Y = data[:,4]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4)

# %%
svn = SVC()
svn.fit(X_train, y_train)
predictions = svn.predict(X_test)
# Calculate the accuracy
accuracy_score(y_test, predictions)
# Out:
# 0.9166666666666666

# %%
print(classification_report(y_test, predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        21
# Iris-versicolor       0.80      0.94      0.86        17
#  Iris-virginica       0.95      0.82      0.88        22
#
#        accuracy                           0.92        60
#       macro avg       0.92      0.92      0.91        60
#    weighted avg       0.92      0.92      0.92        60
